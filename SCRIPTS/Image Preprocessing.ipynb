# %%
import zipfile

# Update the path to the absolute path
zip_path = "/sfs/weka/scratch/axu5pa/DS_4002_Project_3/PH2 Dataset images.zip"

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # List all files in the zip
    file_list = zip_ref.namelist()
    print("Files in zip:", file_list)
# Out:
# Files in zip: ['PH2 Dataset images/', '__MACOSX/._PH2 Dataset images', 'PH2 Dataset images/IMD168/', '__MACOSX/PH2 Dataset images/._IMD168', 'PH2 Dataset images/IMD157/', '__MACOSX/PH2 Dataset images/._IMD157', 'PH2 Dataset images/IMD365/', '__MACOSX/PH2 Dataset images/._IMD365', 'PH2 Dataset images/IMD396/', '__MACOSX/PH2 Dataset images/._IMD396', 'PH2 Dataset images/IMD150/', '__MACOSX/PH2 Dataset images/._IMD150', 'PH2 Dataset images/IMD159/', '__MACOSX/PH2 Dataset images/._IMD159', 'PH2 Dataset images/IMD166/', '__MACOSX/PH2 Dataset images/._IMD166', 'PH2 Dataset images/IMD398/', '__MACOSX/PH2 Dataset images/._IMD398', 'PH2 Dataset images/IMD161/', '__MACOSX/PH2 Dataset images/._IMD161', 'PH2 Dataset images/IMD135/', '__MACOSX/PH2 Dataset images/._IMD135', 'PH2 Dataset images/IMD132/', '__MACOSX/PH2 Dataset images/._IMD132', 'PH2 Dataset images/IMD331/', '__MACOSX/PH2 Dataset images/._IMD331', 'PH2 Dataset images/IMD103/', '__MACOSX/PH2 Dataset images/._IMD103', 'PH2 Dataset images/IMD399/', '__MACOSX/PH2 Dataset images/._IMD399', 'PH2 Dataset images/IMD160/', '__MACOSX/PH2 Dataset images/._IMD160', 'PH2 Dataset images/IMD397/', '__MACOSX/PH2 Dataset images/._IMD397', 'PH2 Dataset images/IMD169/', '__MACOSX/PH2 Dataset images/._IMD169', 'PH2 Dataset images/IMD390/', '__MACOSX/PH2 Dataset images/._IMD390', 'PH2 Dataset images/IMD364/', '__MACOSX/PH2 Dataset images/._IMD364', 'PH2 Dataset images/IMD156/', '__MACOSX/PH2 Dataset images/._IMD156', 'PH2 Dataset images/IMD105/', '__MACOSX/PH2 Dataset images/._IMD105', 'PH2 Dataset images/IMD133/', '__MACOSX/PH2 Dataset images/._IMD133', 'PH2 Dataset images/IMD134/', '__MACOSX/PH2 Dataset images/._IMD134', 'PH2 Dataset images/IMD306/', '__MACOSX/PH2 Dataset images/._IMD306', 'PH2 Dataset images/IMD339/', '__MACOSX/PH2 Dataset images/._IMD339', 'PH2 Dataset images/IMD280/', '__MACOSX/PH2 Dataset images/._IMD280', 'PH2 Dataset images/IMD041/', '__MACOSX/PH2 Dataset images/._IMD041', 'PH2 Dataset images/IMD425/', '__MACOSX/PH2 Dataset images/._IMD425', 'PH2 Dataset images/IMD048/', '__MACOSX/PH2 Dataset images/._IMD048', 'PH2 Dataset images/IMD413/', '__MACOSX/PH2 Dataset images/._IMD413', 'PH2 Dataset images/IMD242/', '__MACOSX/PH2 Dataset images/._IMD242', 'PH2 Dataset images/IMD024/', '__MACOSX/PH2 Dataset images/._IMD024', 'PH2 Dataset images/IMD023/', '__MACOSX/PH2 Dataset images/._IMD023', 'PH2 Dataset images/IMD211/', '__MACOSX/PH2 Dataset images/._IMD211', 'PH2 Dataset images/IMD015/', '__MACOSX/PH2 Dataset images/._IMD015', 'PH2 Dataset images/IMD085/', '__MACOSX/PH2 Dataset images/._IMD085', 'PH2 Dataset images/IMD243/', '__MACOSX/PH2 Dataset images/._IMD243', 'PH2 Dataset images/IMD049/', '__MACOSX/PH2 Dataset images/._IMD049', 'PH2 Dataset images/IMD076/', '__MACOSX/PH2 Dataset images/._IMD076', 'PH2 Dataset images/IMD040/', '__MACOSX/PH2 Dataset images/._IMD040', 'PH2 Dataset images/IMD424/', '__MACOSX/PH2 Dataset images/._IMD424', 'PH2 Dataset images/IMD078/', '__MACOSX/PH2 Dataset images/._IMD078', 'PH2 Dataset images/IMD423/', '__MACOSX/PH2 Dataset images/._IMD423', 'PH2 Dataset images/IMD047/', '__MACOSX/PH2 Dataset images/._IMD047', 'PH2 Dataset images/IMD013/', '__MACOSX/PH2 Dataset images/._IMD013', 'PH2 Dataset images/IMD226/', '__MACOSX/PH2 Dataset images/._IMD226', 'PH2 Dataset images/IMD014/', '__MACOSX/PH2 Dataset images/._IMD014', 'PH2 Dataset images/IMD219/', '__MACOSX/PH2 Dataset images/._IMD219', 'PH2 Dataset images/IMD210/', '__MACOSX/PH2 Dataset images/._IMD210', 'PH2 Dataset images/IMD022/', '__MACOSX/PH2 Dataset images/._IMD022', 'PH2 Dataset images/IMD025/', '__MACOSX/PH2 Dataset images/._IMD025', 'PH2 Dataset images/IMD038/', '__MACOSX/PH2 Dataset images/._IMD038', 'PH2 Dataset images/IMD009/', '__MACOSX/PH2 Dataset images/._IMD009', 'PH2 Dataset images/IMD036/', '__MACOSX/PH2 Dataset images/._IMD036', 'PH2 Dataset images/IMD204/', '__MACOSX/PH2 Dataset images/._IMD204', 'PH2 Dataset images/IMD203/', '__MACOSX/PH2 Dataset images/._IMD203', 'PH2 Data ...

# %%
import os
print(os.getcwd())
# Out:
# /sfs/weka/scratch/axu5pa/DS_4002_Project_3/PH2Dataset

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/axu5pa/.local/lib/python3.11/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/site-packages (from opencv-python) (1.24.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
from PIL import Image
import cv2
import shutil

# Define the path to the images folder
images_path = "/sfs/weka/scratch/axu5pa/DS_4002_Project_3/PH2Dataset/Images"

# Define an output folder for normalized images
output_folder = "./normalized_images"
os.makedirs(output_folder, exist_ok=True)

# Function to normalize an image
def normalize_image(image):
    image_array = np.asarray(image, dtype=np.float32)  # Convert to NumPy array
    normalized_array = image_array / 255.0  # Normalize to [0, 1]
    return normalized_array

# Function to enhance contrast using histogram equalization
def enhance_contrast(image):
    # Convert the image to OpenCV format (NumPy array)
    image_array = np.asarray(image)

    # Convert to LAB color space for better contrast enhancement
    lab = cv2.cvtColor(image_array, cv2.COLOR_RGB2LAB)

    # Apply histogram equalization to the L channel
    l, a, b = cv2.split(lab)
    l_eq = cv2.equalizeHist(l)
    lab_eq = cv2.merge((l_eq, a, b))

    # Convert back to RGB color space
    enhanced_image = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2RGB)
    return enhanced_image

# Merge lesion and base images
def merge_images(base_image, lesion_image):
    # Ensure both images have the same size
    lesion_image = lesion_image.convert("L")  # Convert to grayscale for masking
    base_image = base_image.resize(lesion_image.size, Image.Resampling.LANCZOS)
    
    # Create a mask where white areas in lesion image are preserved
    mask = np.array(lesion_image) > 0  # Convert lesion image to a binary mask
    base_array = np.array(base_image)  # Convert base image to array
    
    # Apply the mask to the base image
    masked_image_array = np.zeros_like(base_array)  # Create a black image of same size
    masked_image_array[mask] = base_array[mask]  # Apply lesion area from base image
    
    # Convert back to PIL Image
    masked_image = Image.fromarray(masked_image_array)
    return masked_image

# List all files in the images folder
image_files = os.listdir(images_path)

# Check if the folder contains any files
if not image_files:
    print("No files found in the images folder.")
else:
    # Loop through the files and process them
    for image_file in image_files:
        # Filter only bmp images (base and lesion)
        if image_file.endswith('.bmp'):
            try:
                # Check if the file is a base or lesion image
                if '_lesion' not in image_file and '_Label' not in image_file:
                    base_image_path = os.path.join(images_path, image_file)
                    base_name = os.path.splitext(image_file)[0]
                    lesion_image_path = os.path.join(images_path, f"{base_name}_lesion.bmp")
                    
                    if os.path.exists(lesion_image_path):
                        print(f"Processing: {base_name}")
                        
                        # Open the base and lesion images
                        with Image.open(base_image_path) as base_img, Image.open(lesion_image_path) as lesion_img:
                            # Merge the images
                            merged_image = merge_images(base_img, lesion_img)

                            # Enhance contrast
                            enhanced_image = enhance_contrast(merged_image)

                            # Normalize the image
                            normalized_array = normalize_image(enhanced_image)

                            # Resize the image to 256x256
                            resized_image = Image.fromarray((normalized_array * 255).astype(np.uint8)).resize((256, 256))

                            # Save the normalized image
                            output_path = os.path.join(output_folder, f"{base_name}_merged.bmp")
                            resized_image.save(output_path)

                            # Confirm the image is saved
                            print(f"Processed and saved: {output_path}")
                    else:
                        print(f"No corresponding lesion file found for {base_name}")
            except Exception as e:
                print(f"Error processing file {image_file}: {e}")
# Out:
# Processing: IMD417
# Processed and saved: ./normalized_images/IMD417_merged.bmp
# Processing: IMD254
# Processed and saved: ./normalized_images/IMD254_merged.bmp
# Processing: IMD020
# Processed and saved: ./normalized_images/IMD020_merged.bmp
# Processing: IMD039
# Processed and saved: ./normalized_images/IMD039_merged.bmp
# Processing: IMD175
# Processed and saved: ./normalized_images/IMD175_merged.bmp
# Processing: IMD279
# Processed and saved: ./normalized_images/IMD279_merged.bmp
# Processing: IMD155
# Processed and saved: ./normalized_images/IMD155_merged.bmp
# Processing: IMD328
# Processed and saved: ./normalized_images/IMD328_merged.bmp
# Processing: IMD085
# Processed and saved: ./normalized_images/IMD085_merged.bmp
# Processing: IMD142
# Processed and saved: ./normalized_images/IMD142_merged.bmp
# Processing: IMD312
# Processed and saved: ./normalized_images/IMD312_merged.bmp
# Processing: IMD143
# Processed and saved: ./normalized_images/IMD143_merged.bmp
# Processing: IMD154
# Processed and saved: ./normalized_images/IMD154_merged.bmp
# Processing: IMD392
# Processed and saved: ./normalized_images/IMD392_merged.bmp
# Processing: IMD199
# Processed and saved: ./normalized_images/IMD199_merged.bmp
# Processing: IMD038
# Processed and saved: ./normalized_images/IMD038_merged.bmp
# Processing: IMD411
# Processed and saved: ./normalized_images/IMD411_merged.bmp
# Processing: IMD375
# Processed and saved: ./normalized_images/IMD375_merged.bmp
# Processing: IMD203
# Processed and saved: ./normalized_images/IMD203_merged.bmp
# Processing: IMD425
# Processed and saved: ./normalized_images/IMD425_merged.bmp
# Processing: IMD177
# Processed and saved: ./normalized_images/IMD177_merged.bmp
# Processing: IMD348
# Processed and saved: ./normalized_images/IMD348_merged.bmp
# Processing: IMD381
# Processed and saved: ./normalized_images/IMD381_merged.bmp
# Processing: IMD162
# Processed and saved: ./normalized_images/IMD162_merged.bmp
# Processing: IMD090
# Processed and saved: ./normalized_images/IMD090_merged.bmp
# Processing: IMD349
# Processed and saved: ./normalized_images/IMD349_merged.bmp
# Processing: IMD120
# Processed and saved: ./normalized_images/IMD120_merged.bmp
# Processing: IMD166
# Processed and saved: ./normalized_images/IMD166_merged.bmp
# Processing: IMD065
# Processed and saved: ./normalized_images/IMD065_merged.bmp
# Processing: IMD064
# Processed and saved: ./normalized_images/IMD064_merged.bmp
# Processing: IMD031
# Processed and saved: ./normalized_images/IMD031_merged.bmp
# Processing: IMD427
# Processed and saved: ./normalized_images/IMD427_merged.bmp
# Processing: IMD410
# Processed and saved: ./normalized_images/IMD410_merged.bmp
# Processing: IMD076
# Processed and saved: ./normalized_images/IMD076_merged.bmp
# Processing: IMD211
# Processed and saved: ./normalized_images/IMD211_merged.bmp
# Processing: IMD210
# Processed and saved: ./normalized_images/IMD210_merged.bmp
# Processing: IMD278
# Processed and saved: ./normalized_images/IMD278_merged.bmp
# Processing: IMD200
# Processed and saved: ./normalized_images/IMD200_merged.bmp
# Processing: IMD405
# Processed and saved: ./normalized_images/IMD405_merged.bmp
# Processing: IMD118
# Processed and saved: ./normalized_images/IMD118_merged.bmp
# Processing: IMD125
# Processed and saved: ./normalized_images/IMD125_merged.bmp
# Processing: IMD360
# Processed and saved: ./normalized_images/IMD360_merged.bmp
# Processing: IMD339
# Processed and saved: ./normalized_images/IMD339_merged.bmp
# Processing: IMD430
# Processed and saved: ./normalized_images/IMD430_merged.bmp
# Processing: IMD399
# Processed and saved: ./normalized_images/IMD399_merged.bmp
# Processing: IMD027
# Processed and saved: ./normalized_images/IMD027_merged.bmp
# Processing: IMD383
# Processed and saved: ./normalized_images/IMD383_merged.bmp
# Processing: IMD088
# Processed and saved: ./normalized_images/IMD088_merged.bmp
# Processing: IMD434
# Processed and saved: ./normalized_images/IMD434_merged.bmp
# Processing: IMD014
# Processed and saved: ./normalized_images/IMD014_merged.bmp
# Processing: IMD418
# Processed and saved: ./normalized_images/IMD418_merged.bmp
# Processing: IMD048
# Processed and saved: ./normalized_images/IMD048_merged.bmp
# Processing: IMD156
# Processed and saved: ./normalized_images/IMD156_merged.bmp
# Processing: IMD280
# Processed and saved: ./normalized_images/IMD280_merged.bmp
# Processing: IMD429
# Processed and saved: ./normalized_images/IMD429_merged.bmp
# Processing: IMD043
# Processed and saved: ./normalized_images/IMD043_merged.bmp
# Processing: IMD017
# Processed and saved: ./normalized_images/IMD017_merged.bmp
# Processing: IMD160
# Processed and saved: ./normalized_images/IMD160_merged.bmp
# Processing: IMD126
# Processed and saved: ./normalized_images/IMD126_merged.bmp
# No corresponding lesion file found for IMD002-checkpoint
# Processing: IMD049
# Processed and saved: ./normalized_images/IMD049_merged.bmp
# Processing: IMD061
# Processed and saved: ./normalized_images/IMD061_merged.bmp
# Processing: IMD149
# Processed and saved: ./normalized_images/IMD149_merged.bmp
# Processing: IMD016
# Processed and saved: ./normalized_images/IMD016_merged.bmp
# Processing: IMD021
# Processed and saved: ./normalized_images/IMD021_merged.bmp
# Processing: IMD030
# Processed and saved: ./normalized_images/IMD030_merged.bmp
# Processing: IMD137
# Processed and saved: ./normalized_images/IMD137_merged.bmp
# Processing: IMD171
# Processed and saved: ./normalized_images/IMD171_merged.bmp
# Processing: IMD371
# Processed and saved: ./normalized_images/IMD371_merged.bmp
# Processing: IMD108
# Processed and saved: ./normalized_images/IMD108_merged.bmp
# Processing: IMD404
# Processed and saved: ./normalized_images/IMD404_merged.bmp
# Processing: IMD256
# Processed and saved: ./normalized_images/IMD256_merged.bmp
# Processing: IMD015
# Processed and saved: ./normalized_images/IMD015_merged.bmp
# Processing: IMD147
# Processed and saved: ./normalized_images/IMD147_merged.bmp
# Processing: IMD368
# Processed and saved: ./normalized_images/IMD368_merged.bmp
# Processing: IMD380
# Processed and saved: ./normalized_images/IMD380_merged.bmp
# Processing: IMD013
# Processed and saved: ./normalized_images/IMD013_merged.bmp
# Processing: IMD170
# Processed and saved: ./normalized_images/IMD170_merged.bmp
# Processing: IMD420
# Processed and saved: ./normalized_images/IMD420_merged.bmp
# Processing: IMD004
# Processed and saved: ./normalized_images/IMD004_merged.bmp
# Processing: IMD112
# Processed and saved: ./normalized_images/IMD112_merged.bmp
# Processing: IMD385
# Processed and saved: ./normalized_images/IMD385_merged.bmp
# Processing: IMD037
# Processed and saved: ./normalized_images/IMD037_merged.bmp
# Processing: IMD285
# Processed and saved: ./normalized_images/IMD285_merged.bmp
# Processing: IMD389
# Processed and saved: ./normalized_images/IMD389_merged.bmp
# Processing: IMD419
# Processed and saved: ./normalized_images/IMD419_merged.bmp
# Processing: IMD400
# Processed and saved: ./normalized_images/IMD400_merged.bmp
# Processing: IMD132
# Processed and saved: ./normalized_images/IMD132_merged.bmp
# Processing: IMD133
# Processed and saved: ./normalized_images/IMD133_merged.bmp
# Processing: IMD372
# Processed and saved: ./normalized_images/IMD372_merged.bmp
# Processing: IMD006
# Processed and saved: ./normalized_images/IMD006_merged.bmp
# Processing: IMD409
# Processed and saved: ./normalized_images/IMD409_merged.bmp
# Processing: IMD347
# Processed and saved: ./normalized_images/IMD347_merged.bmp
# Processing: IMD045
# Processed and saved: ./normalized_images/IMD045_merged.bmp
# Processing: IMD101
# Processed and saved: ./normalized_images/IMD101_merged.bmp
# Processing: IMD032
# Processed and saved: ./normalized_images/IMD032_merged.bmp
# Processing: IMD159
# Processed and saved: ./normalized_images/IMD159_merged.bmp
# Processing: IMD226
# Processed and saved: ./normalized_images/IMD226_merged.bmp
# Processing: IMD398
# Processed and saved: ./normalized_images/IMD398_merged.bmp
# Processing: IMD240
# Processed and saved: ./normalized_images/IMD240_merged.bmp
# Processing: IMD044
# Processed and saved: ./normalized_images/IMD044_merged.bmp
# Processing: IMD035
# Processed and saved: ./normalized_images/IMD035_merged.bmp
# Processing: IMD196
# Processed and saved: ./normalized_images/IMD196_merged.bmp
# Processing: IMD388
# Processed and saved: ./normalized_images/IMD388_merged.bmp
# Processing: IMD197
# Processed and saved: ./normalized_images/IMD197_merged.bmp
# Processing: IMD407
# Processed and saved: ./normalized_images/IMD407_merged.bmp
# Processing: IMD408
# Processed and saved: ./normalized_images/IMD408_merged.bmp
# Processing: IMD436
# Processed and saved: ./normalized_images/IMD436_merged.bmp
# Processing: IMD386
# Processed and saved: ./normalized_images/IMD386_merged.bmp
# Processing: IMD105
# Processed and saved: ./normalized_images/IMD105_merged.bmp
# Processing: IMD107
# Processed and saved: ./normalized_images/IMD107_merged.bmp
# Processing: IMD009
# Processed and saved: ./normalized_images/IMD009_merged.bmp
# Processing: IMD138
# Processed and saved: ./normalized_images/IMD138_merged.bmp
# Processing: IMD356
# Processed and saved: ./normalized_images/IMD356_merged.bmp
# Processing: IMD041
# Processed and saved: ./normalized_images/IMD041_merged.bmp
# Processing: IMD206
# Processed and saved: ./normalized_images/IMD206_merged.bmp
# Processing: IMD433
# Processed and saved: ./normalized_images/IMD433_merged.bmp
# Processing: IMD040
# Processed and saved: ./normalized_images/IMD040_merged.bmp
# Processing: IMD022
# Processed and saved: ./normalized_images/IMD022_merged.bmp
# Processing: IMD370
# Processed and saved: ./normalized_images/IMD370_merged.bmp
# Processing: IMD437
# Processed and saved: ./normalized_images/IMD437_merged.bmp
# Processing: IMD304
# Processed and saved: ./normalized_images/IMD304_merged.bmp
# Processing: IMD024
# Processed and saved: ./normalized_images/IMD024_merged.bmp
# Processing: IMD395
# Processed and saved: ./normalized_images/IMD395_merged.bmp
# Processing: IMD153
# Processed and saved: ./normalized_images/IMD153_merged.bmp
# Processing: IMD008
# Processed and saved: ./normalized_images/IMD008_merged.bmp
# Processing: IMD394
# Processed and saved: ./normalized_images/IMD394_merged.bmp
# Processing: IMD331
# Processed and saved: ./normalized_images/IMD331_merged.bmp
# Processing: IMD204
# Processed and saved: ./normalized_images/IMD204_merged.bmp
# Processing: IMD075
# Processed and saved: ./normalized_images/IMD075_merged.bmp
# Processing: IMD390
# Processed and saved: ./normalized_images/IMD390_merged.bmp
# Processing: IMD396
# Processed and saved: ./normalized_images/IMD396_merged.bmp
# Processing: IMD379
# Processed and saved: ./normalized_images/IMD379_merged.bmp
# Processing: IMD384
# Processed and saved: ./normalized_images/IMD384_merged.bmp
# Processing: IMD374
# Processed and saved: ./normalized_images/IMD374_merged.bmp
# Processing: IMD382
# Processed and saved: ./normalized_images/IMD382_merged.bmp
# Processing: IMD376
# Processed and saved: ./normalized_images/IMD376_merged.bmp
# Processing: IMD306
# Processed and saved: ./normalized_images/IMD306_merged.bmp
# Processing: IMD139
# Processed and saved: ./normalized_images/IMD139_merged.bmp
# Processing: IMD364
# Processed and saved: ./normalized_images/IMD364_merged.bmp
# Processing: IMD402
# Processed and saved: ./normalized_images/IMD402_merged.bmp
# Processing: IMD036
# Processed and saved: ./normalized_images/IMD036_merged.bmp
# Processing: IMD243
# Processed and saved: ./normalized_images/IMD243_merged.bmp
# Processing: IMD168
# Processed and saved: ./normalized_images/IMD168_merged.bmp
# Processing: IMD424
# Processed and saved: ./normalized_images/IMD424_merged.bmp
# Processing: IMD091
# Processed and saved: ./normalized_images/IMD091_merged.bmp
# Processing: IMD176
# Processed and saved: ./normalized_images/IMD176_merged.bmp
# Processing: IMD134
# Processed and saved: ./normalized_images/IMD134_merged.bmp
# Processing: IMD173
# Processed and saved: ./normalized_images/IMD173_merged.bmp
# Processing: IMD367
# Processed and saved: ./normalized_images/IMD367_merged.bmp
# Processing: IMD169
# Processed and saved: ./normalized_images/IMD169_merged.bmp
# Processing: IMD251
# Processed and saved: ./normalized_images/IMD251_merged.bmp
# Processing: IMD050
# Processed and saved: ./normalized_images/IMD050_merged.bmp
# Processing: IMD042
# Processed and saved: ./normalized_images/IMD042_merged.bmp
# Processing: IMD219
# Processed and saved: ./normalized_images/IMD219_merged.bmp
# Processing: IMD058
# Processed and saved: ./normalized_images/IMD058_merged.bmp
# Processing: IMD019
# Processed and saved: ./normalized_images/IMD019_merged.bmp
# Processing: IMD164
# Processed and saved: ./normalized_images/IMD164_merged.bmp
# Processing: IMD208
# Processed and saved: ./normalized_images/IMD208_merged.bmp
# Processing: IMD207
# Processed and saved: ./normalized_images/IMD207_merged.bmp
# Processing: IMD198
# Processed and saved: ./normalized_images/IMD198_merged.bmp
# Processing: IMD435
# Processed and saved: ./normalized_images/IMD435_merged.bmp
# Processing: IMD146
# Processed and saved: ./normalized_images/IMD146_merged.bmp
# Processing: IMD150
# Processed and saved: ./normalized_images/IMD150_merged.bmp
# Processing: IMD182
# Processed and saved: ./normalized_images/IMD182_merged.bmp
# Processing: IMD025
# Processed and saved: ./normalized_images/IMD025_merged.bmp
# Processing: IMD023
# Processed and saved: ./normalized_images/IMD023_merged.bmp
# Processing: IMD092
# Processed and saved: ./normalized_images/IMD092_merged.bmp
# Processing: IMD033
# Processed and saved: ./normalized_images/IMD033_merged.bmp
# Processing: IMD144
# Processed and saved: ./normalized_images/IMD144_merged.bmp
# Processing: IMD421
# Processed and saved: ./normalized_images/IMD421_merged.bmp
# Processing: IMD431
# Processed and saved: ./normalized_images/IMD431_merged.bmp
# Processing: IMD284
# Processed and saved: ./normalized_images/IMD284_merged.bmp
# Processing: IMD365
# Processed and saved: ./normalized_images/IMD365_merged.bmp
# Processing: IMD078
# Processed and saved: ./normalized_images/IMD078_merged.bmp
# Processing: IMD010
# Processed and saved: ./normalized_images/IMD010_merged.bmp
# Processing: IMD369
# Processed and saved: ./normalized_images/IMD369_merged.bmp
# Processing: IMD161
# Processed and saved: ./normalized_images/IMD161_merged.bmp
# Processing: IMD423
# Processed and saved: ./normalized_images/IMD423_merged.bmp
# Processing: IMD057
# Processed and saved: ./normalized_images/IMD057_merged.bmp
# Processing: IMD413
# Processed and saved: ./normalized_images/IMD413_merged.bmp
# Processing: IMD242
# Processed and saved: ./normalized_images/IMD242_merged.bmp
# Processing: IMD103
# Processed and saved: ./normalized_images/IMD103_merged.bmp
# Processing: IMD397
# Processed and saved: ./normalized_images/IMD397_merged.bmp
# Processing: IMD426
# Processed and saved: ./normalized_images/IMD426_merged.bmp
# Processing: IMD140
# Processed and saved: ./normalized_images/IMD140_merged.bmp
# Processing: IMD406
# Processed and saved: ./normalized_images/IMD406_merged.bmp
# Processing: IMD152
# Processed and saved: ./normalized_images/IMD152_merged.bmp
# Processing: IMD080
# Processed and saved: ./normalized_images/IMD080_merged.bmp
# Processing: IMD305
# Processed and saved: ./normalized_images/IMD305_merged.bmp
# Processing: IMD157
# Processed and saved: ./normalized_images/IMD157_merged.bmp
# Processing: IMD135
# Processed and saved: ./normalized_images/IMD135_merged.bmp
# Processing: IMD003
# Processed and saved: ./normalized_images/IMD003_merged.bmp
# Processing: IMD018
# Processed and saved: ./normalized_images/IMD018_merged.bmp
# Processing: IMD403
# Processed and saved: ./normalized_images/IMD403_merged.bmp
# Processing: IMD063
# Processed and saved: ./normalized_images/IMD063_merged.bmp
# Processing: IMD393
# Processed and saved: ./normalized_images/IMD393_merged.bmp
# Processing: IMD432
# Processed and saved: ./normalized_images/IMD432_merged.bmp
# Processing: IMD378
# Processed and saved: ./normalized_images/IMD378_merged.bmp
# Processing: IMD047
# Processed and saved: ./normalized_images/IMD047_merged.bmp
# Processing: IMD002
# Processed and saved: ./normalized_images/IMD002_merged.bmp

# %%
# Check if output folder contains files
output_files = os.listdir(output_folder)
if not output_files:
    print("No files saved to the output folder.")
else:
    print(f"Files saved to the output folder: {output_files}")

# Compress the normalized images folder into a zip file
shutil.make_archive("normalized_merged_images", 'zip', output_folder)

# Confirmation of zip file creation
print("Normalized and merged images are zipped and ready to download.")
# Out:
# Files saved to the output folder: ['IMD279_merged.bmp', 'IMD420_merged.bmp', 'IMD112_merged.bmp', 'IMD075_merged.bmp', 'IMD156_merged.bmp', 'IMD256_merged.bmp', 'IMD403_merged.bmp', 'IMD304_merged.bmp', 'IMD385_merged.bmp', 'IMD153_merged.bmp', 'IMD133_merged.bmp', 'IMD432_merged.bmp', 'IMD058_merged.bmp', 'IMD285_merged.bmp', 'IMD170_merged.bmp', 'IMD413_merged.bmp', 'IMD038_merged.bmp', 'IMD437_merged.bmp', 'IMD154_merged.bmp', 'IMD003_merged.bmp', 'IMD105_merged.bmp', 'IMD057_merged.bmp', 'IMD132_merged.bmp', 'IMD080_merged.bmp', 'IMD107_merged.bmp', 'IMD418_merged.bmp', 'IMD368_merged.bmp', 'IMD203_merged.bmp', 'IMD126_merged.bmp', 'IMD397_merged.bmp', 'IMD103_merged.bmp', 'IMD138_merged.bmp', 'IMD161_merged.bmp', 'IMD328_merged.bmp', 'IMD037_merged.bmp', 'IMD383_merged.bmp', 'IMD417_merged.bmp', 'IMD434_merged.bmp', 'IMD140_merged.bmp', 'IMD426_merged.bmp', 'IMD025_merged.bmp', 'IMD389_merged.bmp', 'IMD019_merged.bmp', 'IMD378_merged.bmp', 'IMD243_merged.bmp', 'IMD006_merged.bmp', 'IMD018_merged.bmp', 'IMD312_merged.bmp', 'IMD254_merged.bmp', 'IMD155_merged.bmp', 'IMD042_merged.bmp', 'IMD091_merged.bmp', 'IMD024_merged.bmp', 'IMD039_merged.bmp', 'IMD063_merged.bmp', 'IMD157_merged.bmp', 'IMD408_merged.bmp', 'IMD251_merged.bmp', 'IMD371_merged.bmp', 'IMD149_merged.bmp', 'IMD061_merged.bmp', 'IMD013_merged.bmp', 'IMD404_merged.bmp', 'IMD208_merged.bmp', 'IMD143_merged.bmp', 'IMD407_merged.bmp', 'IMD022_merged.bmp', 'IMD125_merged.bmp', 'IMD169_merged.bmp', 'IMD381_merged.bmp', 'IMD027_merged.bmp', 'IMD278_merged.bmp', 'IMD036_merged.bmp', 'IMD048_merged.bmp', 'IMD433_merged.bmp', 'IMD088_merged.bmp', 'IMD050_merged.bmp', 'IMD372_merged.bmp', 'IMD090_merged.bmp', 'IMD047_merged.bmp', 'IMD041_merged.bmp', 'IMD150_merged.bmp', 'IMD135_merged.bmp', 'IMD349_merged.bmp', 'IMD394_merged.bmp', 'IMD064_merged.bmp', 'IMD365_merged.bmp', 'IMD367_merged.bmp', 'IMD356_merged.bmp', 'IMD078_merged.bmp', 'IMD380_merged.bmp', 'IMD360_merged.bmp', 'IMD429_merged.bmp', 'IMD206_merged.bmp', 'IMD419_merged.bmp', 'IMD384_merged.bmp', 'IMD173_merged.bmp', 'IMD134_merged.bmp', 'IMD035_merged.bmp', 'IMD436_merged.bmp', 'IMD118_merged.bmp', 'IMD369_merged.bmp', 'IMD425_merged.bmp', 'IMD175_merged.bmp', 'IMD049_merged.bmp', 'IMD010_merged.bmp', 'IMD392_merged.bmp', 'IMD017_merged.bmp', 'IMD396_merged.bmp', 'IMD144_merged.bmp', 'IMD423_merged.bmp', 'IMD182_merged.bmp', 'IMD076_merged.bmp', 'IMD370_merged.bmp', 'IMD379_merged.bmp', 'IMD085_merged.bmp', 'IMD364_merged.bmp', 'IMD152_merged.bmp', 'IMD390_merged.bmp', 'IMD400_merged.bmp', 'IMD196_merged.bmp', 'IMD159_merged.bmp', 'IMD108_merged.bmp', 'IMD347_merged.bmp', 'IMD030_merged.bmp', 'IMD409_merged.bmp', 'IMD284_merged.bmp', 'IMD014_merged.bmp', 'IMD405_merged.bmp', 'IMD031_merged.bmp', 'IMD427_merged.bmp', 'IMD399_merged.bmp', 'IMD207_merged.bmp', 'IMD226_merged.bmp', 'IMD306_merged.bmp', 'IMD092_merged.bmp', 'IMD147_merged.bmp', 'IMD411_merged.bmp', 'IMD219_merged.bmp', 'IMD160_merged.bmp', 'IMD240_merged.bmp', 'IMD004_merged.bmp', 'IMD430_merged.bmp', 'IMD204_merged.bmp', 'IMD210_merged.bmp', 'IMD146_merged.bmp', 'IMD199_merged.bmp', 'IMD176_merged.bmp', 'IMD402_merged.bmp', 'IMD045_merged.bmp', 'IMD020_merged.bmp', 'IMD388_merged.bmp', 'IMD043_merged.bmp', 'IMD065_merged.bmp', 'IMD398_merged.bmp', 'IMD386_merged.bmp', 'IMD242_merged.bmp', 'IMD162_merged.bmp', 'IMD424_merged.bmp', 'IMD376_merged.bmp', 'IMD168_merged.bmp', 'IMD021_merged.bmp', 'IMD198_merged.bmp', 'IMD164_merged.bmp', 'IMD382_merged.bmp', 'IMD177_merged.bmp', 'IMD406_merged.bmp', 'IMD339_merged.bmp', 'IMD008_merged.bmp', 'IMD139_merged.bmp', 'IMD280_merged.bmp', 'IMD002_merged.bmp', 'IMD120_merged.bmp', 'IMD197_merged.bmp', 'IMD421_merged.bmp', 'IMD166_merged.bmp', 'IMD015_merged.bmp', 'IMD040_merged.bmp', 'IMD375_merged.bmp', 'IMD023_merged.bmp', 'IMD305_merged.bmp', 'IMD348_merged.bmp', 'IMD016_merged.bmp', 'IMD435_merged.bmp', 'IMD171_merged.bmp', 'IMD410_merged.bmp', 'IMD211_merged.bmp', 'IMD374_merged.bmp', 'IMD101_merged.bm ...
# Normalized and merged images are zipped and ready to download.

# %%
pip install torch torchvision torchaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/d1/35/e8b2daf02ce933e4518e6f5682c72fd0ed66c15910ea1fb4168f442b71c4/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata
#   Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/de/e9/e190ecec448d5a2abad8348cf085fcb39962a491e3f40dcb023721e04feb/torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl.metadata
#   Downloading torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Obtaining dependency information for torchaudio from https://files.pythonhosted.org/packages/41/33/0f21b15f8e231bb55578f6b32e8c18675585b7bf97cb0aee96b1591e4193/torchaudio-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata
#   Downloading torchaudio-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting filelock (from torch)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/b9/f8/feced7779d755758a52d1f6635d990b8d98dc0a29fa568bbe0625f18fdf3/filelock-3.16.1-py3-none-any.whl.metadata
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Obtaining dependency information for typing-extensions>=4.8.0 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: networkx in /apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/site-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Obtaining dependency information for nvidia-cuda-nvrtc-cu12==12.4.127 from https://files.pythonhosted.org/packages/2c/14/91ae57cd4db3f9ef7aa99f4019cfa8d54cb4caa7e00975df6467e9725a9f/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Obtaining dependency information for nvidia-cuda-runtime-cu12==12.4.127 from https://files.pythonhosted.org/packages/ea/27/1795d86fe88ef397885f2e580ac37628ed058a92ed2c39dc8eac3adf0619/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Obtaining dependency information for nvidia-cuda-cupti-cu12==12.4.127 from https://files.pythonhosted.org/packages/67/42/f4f60238e8194a3106d06a058d494b18e006c10bb2b915655bd9f6ea4cb1/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Obtaining dependency information for nvidia-cudnn-cu12==9.1.0.70 from https://files.pythonhosted.org/packages/9f/fd/713452cd72343f682b1c7b9321e23829f00b842ceaedcda96e742ea0b0b3/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Obtaining dependency information for nvidia-cublas-cu12==12.4.5.8 from https://files.pythonhosted.org/packages/ae/71/1c91302526c45ab494c23f61c7a84aa568b8c1f9d196efa5993957faf906/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Obtaining dependency information for nvidia-cufft-cu12==11.2.1.3 from https://files.pythonhosted.org/packages/27/94/3266821f65b92b3138631e9c8e7fe1fb513804ac934485a8d05776e1dd43/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Obtaining dependency information for nvidia-curand-cu12==10.3.5.147 from https://files.pythonhosted.org/packages/8a/6d/44ad094874c6f1b9c654f8ed939590bdc408349f137f9b98a3a23ccec411/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Obtaining dependency information for nvidia-cusolver-cu12==11.6.1.9 from https://files.pythonhosted.org/packages/3a/e1/5b9089a4b2a4790dfdea8b3a006052cfecff58139d5a4e34cb1a51df8d6f/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Obtaining dependency information for nvidia-cusparse-cu12==12.3.1.170 from https://files.pythonhosted.org/packages/db/f7/97a9ea26ed4bbbfc2d470994b8b4f338ef663be97b8f677519ac195e113d/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Obtaining dependency information for nvidia-nccl-cu12==2.21.5 from https://files.pythonhosted.org/packages/df/99/12cd266d6233f47d00daf3a72739872bdc10267d0383508b0b9c84a18bb6/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Obtaining dependency information for nvidia-nvtx-cu12==12.4.127 from https://files.pythonhosted.org/packages/87/20/199b8713428322a2f22b722c62b8cc278cc53dffa9705d744484b5035ee9/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Obtaining dependency information for nvidia-nvjitlink-cu12==12.4.127 from https://files.pythonhosted.org/packages/ff/ff/847841bacfbefc97a00036e0fce5a0f086b640756dc38caea5e1bb002655/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch)
#   Obtaining dependency information for triton==3.1.0 from https://files.pythonhosted.org/packages/86/17/d9a5cf4fcf46291856d1e90762e36cbabd2a56c7265da0d1d9508c8e3943/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch)
#   Obtaining dependency information for sympy==1.13.1 from https://files.pythonhosted.org/packages/b2/fe/81695a1aa331a842b582453b605175f419fe8540355886031328089d840a/sympy-1.13.1-py3-none-any.whl.metadata
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Obtaining dependency information for mpmath<1.4,>=1.1.0 from https://files.pythonhosted.org/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl.metadata
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy in /apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /apps/software/standard/core/jupyterlab/3.6.3-py3.11/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 7.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 16.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 28.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 24.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 33.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 35.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 24.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 30.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 34.9 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 82.4 MB/s eta 0:00:00:00:0100:01
# Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 24.0 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 76.2 MB/s eta 0:00:00:00:0100:01
# Downloading torchaudio-2.5.1-cp311-cp311-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 56.3 MB/s eta 0:00:00:00:01
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 57.6 MB/s eta 0:00:00
# Installing collected packages: mpmath, typing-extensions, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   WARNING: The script isympy is installed in '/home/axu5pa/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts proton and proton-viewer are installed in '/home/axu5pa/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2, torchfrtrace and torchrun are installed in '/home/axu5pa/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed filelock-3.16.1 mpmath-1.3.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1 torch-2.5.1 torchaudio-2.5.1 torchvision-0.20.1 triton-3.1.0 typing-extensions-4.12.2
# Note: you may need to restart the kernel to use updated packages.
