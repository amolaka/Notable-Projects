# %% [markdown]
# <a href="https://colab.research.google.com/github/amolaka/DS-3001---Voting-Project/blob/main/merging_voting_and_pop_with_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import files and load in data
# import necessary packages
! pip3 install mapclassify
import geopandas as gpd
import mapclassify
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Load data
md = pd.read_csv('./model_data-2.csv') # Load in model_data (county data)
vdf = pd.read_csv('./voting_data_with_population-2.csv') # merged voting and pop df
md.drop(columns=['Unnamed: 0'], inplace=True)
md.head()
# Out:
# ...
#   Data File Year       County Name  County Code  White alone  \
# 0      2006-2010   Accomack County          1.0        394.0
# 1      2006-2010  Albemarle County          3.0        509.0
# 2      2006-2010  Alleghany County          5.0         75.0
# 3      2006-2010     Amelia County          7.0        152.0
# 4      2006-2010    Amherst County          9.0        323.0
#
#    Black or African American alone  American Indian and Alaska Native alone  \
# 0                             84.0                                     32.0
# 1                            328.0                                    140.0
# 2                            113.0                                      5.0
# 3                            212.0                                     38.0
# 4                            162.0                                     85.0
#
#    Asian alone  Native Hawaiian and Other Pacific Islander alone   0-50K  \
# ...

# %%
# Create an empty list to store the additional data from md
additional_data = []

# Loop through each row in vdf
for index, row in vdf.iterrows():
    year = row['year']

    # Determine the year range based on the year
    if 2006 <= year <= 2010:
        year_range = '2006-2010'
    elif 2010 < year <= 2014:
        year_range = '2010-2014'
    elif 2012 <= year <= 2016:
        year_range = '2012-2016'
    elif 2014 < year <= 2018:
        year_range = '2014-2018'
    elif 2016 <= year <= 2020:
        year_range = '2016-2020'
    else:
        year_range = None  # Handle years outside the specified ranges

    # Filter md for the corresponding year range and county_fips
    additional_row = md[(md['Data File Year'] == year_range) & (md['County Code'] == row['County Code'])]

    if not additional_row.empty:
        additional_value = additional_row.iloc[0]['White alone']  # Replace 'Column_Name' with the actual column you want to extract data from
        additional_data.append(additional_value)
    else:
        additional_data.append(None)  # Append None if no data found

# Add the additional data to vdf
vdf['white'] = additional_data  # Replace 'additional_column' with the name of the column where you want to store the additional data

# Print vdf with the added column
print(vdf)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'County Code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Save the merged dataframe as a CSV file
merged_df.to_csv("merged_data_with_year_ranges.csv", index=False)
