# %% [markdown]
# <a href="https://colab.research.google.com/github/amolaka/DS-3001---Voting-Project/blob/main/voting_data_with_population_cleaned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import necessary packages
! pip3 install mapclassify
import geopandas as gpd
import mapclassify
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.10/dist-packages (2.6.1)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (3.3)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.25.2)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)

# %%
# Load data
md = pd.read_csv('/content/model_data-2.csv') # Load in model_data (county data)
vdf = pd.read_csv('./county_votes_allyears.csv') # Load historical voting data
pop = pd.read_csv('/content/df_melt.csv') # Load the population data

# %%
vdf.drop(columns=['Unnamed: 0'], inplace=True)
vdf.head()
# Out:
#    year     state  county_fips county_name  democrat_votes  republican_votes  \
# 0  2000  VIRGINIA        51001    ACCOMACK            5092              6352
# 1  2000  VIRGINIA        51003   ALBEMARLE           16255             18291
# 2  2000  VIRGINIA        51005   ALLEGHANY            2214              2808
# 3  2000  VIRGINIA        51007      AMELIA            1754              2947
# 4  2000  VIRGINIA        51009     AMHERST            4812              6660
#
#    total_votes
# 0        11444
# 1        34546
# 2         5022
# 3         4701
# 4        11472

# %%
md.drop(columns=['Unnamed: 0'], inplace=True)
md.head()
# Out:
#   Data File Year       County Name  County Code  White alone  \
# 0      2006-2010   Accomack County          1.0        394.0
# 1      2006-2010  Albemarle County          3.0        509.0
# 2      2006-2010  Alleghany County          5.0         75.0
# 3      2006-2010     Amelia County          7.0        152.0
# 4      2006-2010    Amherst County          9.0        323.0
#
#    Black or African American alone  American Indian and Alaska Native alone  \
# 0                             84.0                                     32.0
# 1                            328.0                                    140.0
# 2                            113.0                                      5.0
# 3                            212.0                                     38.0
# 4                            162.0                                     85.0
#
#    Asian alone  Native Hawaiian and Other Pacific Islander alone   0-50K  \
# 0         44.0                                             127.0  1702.0
# 1        223.0                                              43.0  2158.0
# 2         70.0                                             127.0  1012.0
# 3         53.0                                              28.0   978.0
# 4         51.0                                             127.0  1406.0
#
#    50K-100K  ...  Male: Some early_log  Male: High school_log  \
# 0     666.0  ...              6.086775               6.814543
# 1    1278.0  ...              6.523562               6.971669
# 2     447.0  ...              5.579730               6.148468
# 3     515.0  ...              5.796058               6.326149
# 4     635.0  ...              6.016157               6.699500
#
#    Male: Some college or Associate's degree_log  Male: Bachelor's degree_log  \
# 0                                      6.274762                     5.411646
# 1                                      6.626718                     6.342121
# 2                                      5.846439                     4.890349
# 3                                      5.877736                     4.976734
# 4                                      6.304449                     5.117994
#
#    Male: Master's degree or higher_log  Female: Some early_log  \
# 0                             5.786897                5.762051
# 1                             6.838405                6.313548
# 2                             4.779123                5.293305
# 3                             5.187386                4.997212
# 4                             5.370638                6.284134
#
#    Female: High school_log  Female: Some college or Associate's degree_log  \
# 0                 6.833032                                        6.419995
# 1                 6.967909                                        6.938284
# 2                 6.253829                                        5.942799
# 3                 6.364751                                        6.049733
# 4                 6.689599                                        6.298949
#
#    Female: Bachelor's degree_log  Female: Master's degree or higher_log
# 0                       5.537334                               5.710427
# 1                       6.395262                               6.837333
# 2                       5.036953                               5.627621
# 3                       4.927254                               5.863631
# 4                       5.365976                               5.583496
#
# [5 rows x 55 columns]

# %%
md.tail()
# Out:
#      Data File Year          County Name  County Code  White alone  \
# 1062      2016-2020         Suffolk city        800.0          NaN
# 1063      2016-2020  Virginia Beach city        810.0          NaN
# 1064      2016-2020      Waynesboro city        820.0          NaN
# 1065      2016-2020    Williamsburg city        830.0          NaN
# 1066      2016-2020      Winchester city        840.0          NaN
#
#       Black or African American alone  \
# 1062                              NaN
# 1063                              NaN
# 1064                              NaN
# 1065                              NaN
# 1066                              NaN
#
#       American Indian and Alaska Native alone  Asian alone  \
# 1062                                      NaN          NaN
# 1063                                      NaN          NaN
# 1064                                      NaN          NaN
# 1065                                      NaN          NaN
# 1066                                      NaN          NaN
#
#       Native Hawaiian and Other Pacific Islander alone  0-50K  50K-100K  ...  \
# 1062                                               NaN    NaN       NaN  ...
# 1063                                               NaN    NaN       NaN  ...
# 1064                                               NaN    NaN       NaN  ...
# 1065                                               NaN    NaN       NaN  ...
# 1066                                               NaN    NaN       NaN  ...
#
#       Male: Some early_log  Male: High school_log  \
# 1062                   NaN                    NaN
# 1063                   NaN                    NaN
# 1064                   NaN                    NaN
# 1065                   NaN                    NaN
# 1066                   NaN                    NaN
#
#       Male: Some college or Associate's degree_log  \
# 1062                                           NaN
# 1063                                           NaN
# 1064                                           NaN
# 1065                                           NaN
# 1066                                           NaN
#
#       Male: Bachelor's degree_log  Male: Master's degree or higher_log  \
# 1062                          NaN                                  NaN
# 1063                          NaN                                  NaN
# 1064                          NaN                                  NaN
# 1065                          NaN                                  NaN
# 1066                          NaN                                  NaN
#
#       Female: Some early_log  Female: High school_log  \
# 1062                     NaN                      NaN
# 1063                     NaN                      NaN
# 1064                     NaN                      NaN
# 1065                     NaN                      NaN
# 1066                     NaN                      NaN
#
#       Female: Some college or Associate's degree_log  \
# 1062                                             NaN
# 1063                                             NaN
# 1064                                             NaN
# 1065                                             NaN
# 1066                                             NaN
#
#       Female: Bachelor's degree_log  Female: Master's degree or higher_log
# 1062                            NaN                                    NaN
# 1063                            NaN                                    NaN
# 1064                            NaN                                    NaN
# 1065                            NaN                                    NaN
# 1066                            NaN                                    NaN
#
# [5 rows x 55 columns]

# %%
pop.head()
# Out:
#    YEAR   FIPS    AV0AA    B78AA    AV1AA    AV1AB    AT5AA   AT5AB    AL8AA  \
# 0  2000  51001  38305.0  38305.0  18590.0  19715.0  36680.0  1625.0  22535.0
# 1   125  51001  33454.0  33454.0  16230.0  17224.0  31192.0  2262.0  18212.0
# 2   195  51001  32673.0  32673.0  15934.0  16739.0  30148.0  2525.0  18418.0
# 3  2000  51003  79236.0  79236.0  38002.0  41234.0  73483.0  5753.0  39195.0
# 4   125  51003  99484.0  99484.0  47564.0  51920.0  89589.0  9895.0  46267.0
#
#      AL8AB  ...   A88AD    A88AE    AB2AA    BD5AA    AX6AA   CL6AA   AX7AA  \
# 0  13983.0  ...  3781.0   3195.0  34821.0  16309.0  37715.0  6788.0  6788.0
# 1  12696.0  ...  2649.0   4604.0  50250.0  22909.0  33012.0  6678.0  6678.0
# 2  11366.0  ...  2395.0   5072.0  57711.0  26018.0  32325.0  6141.0  6141.0
# 3  33535.0  ...  5153.0  13401.0  63407.0  28852.0  77661.0  5232.0  5232.0
# 4  41638.0  ...  3715.0  18225.0  89768.0  37837.0  93607.0  8321.0  8321.0
#
#      AX7AB   BV8AA    BV8AB
# 0  30927.0   957.0   5291.0
# 1  26334.0  1002.0   5147.0
# 2  26184.0   677.0   6603.0
# 3  72429.0   430.0   8756.0
# 4  85286.0   643.0  13285.0
#
# [5 rows x 162 columns]

# %%
year_range_mapping = {
    2000: 2000,
    2001: 2000,
    2002: 2000,
    2003: 2000,
    2004: 2000,
    2005: 2000,
    2006: 2000,
    2007: 2000,
    2008: 125,
    2009: 125,
    2010: 125,
    2011: 125,
    2012: 125,
    2013: 125,
    2014: 125,
    2015: 195,
    2016: 195,
    2017: 195,
    2018: 195,
    2019: 195,
    2020: 195
}
# Create an empty list to store the population data
population_data = []

# Loop through each row in vdf
for index, row in vdf.iterrows():
    year = row['year']
    population_code = year_range_mapping.get(year)

    # Filter df_melt for the corresponding population code and county_fips
    population_row = pop[(pop['YEAR'] == population_code) & (pop['FIPS'] == row['county_fips'])]

    if not population_row.empty:
        population = population_row.iloc[0]['AV0AA']
        population_data.append(population)
    else:
        population_data.append(None)  # Append None if no population data found

# Add the population data to vdf
vdf['population'] = population_data

# Print vdf with the added population column
print(vdf)
# Out:
#      year     state  county_fips          county_name  democrat_votes  \
# 0    2000  VIRGINIA        51001             ACCOMACK            5092
# 1    2000  VIRGINIA        51003            ALBEMARLE           16255
# 2    2000  VIRGINIA        51005            ALLEGHANY            2214
# 3    2000  VIRGINIA        51007               AMELIA            1754
# 4    2000  VIRGINIA        51009              AMHERST            4812
# ..    ...       ...          ...                  ...             ...
# 798  2020  VIRGINIA        51800         SUFFOLK CITY           28676
# 799  2020  VIRGINIA        51810  VIRGINIA BEACH CITY          117393
# 800  2020  VIRGINIA        51820      WAYNESBORO CITY            4961
# 801  2020  VIRGINIA        51830    WILLIAMSBURG CITY            4790
# 802  2020  VIRGINIA        51840      WINCHESTER CITY            6610
#
#      republican_votes  total_votes  population
# 0                6352        11444     38305.0
# 1               18291        34546     79236.0
# 2                2808         5022     12926.0
# 3                2947         4701     11400.0
# 4                6660        11472     31894.0
# ..                ...          ...         ...
# 798             20082        48758     90093.0
# 799            105087       222480    450201.0
# 800              5507        10468     22140.0
# 801              1963         6753     14927.0
# 802              5221        11831     27897.0
#
# [803 rows x 8 columns]

# %%
vdf.to_csv("voting_data_with_population.csv")

# %% [markdown]
# ## joining the two dfs on county name

# %%
# Step 1: Normalize county names
vdf['county_name'] = vdf['county_name'].str.lower()
md['County Name'] = md['County Name'].str.lower()

# Step 2: Remove "County" from one data frame
md['County Name'] = md['County Name'].str.replace('county', '')

# Make sure each county only has one row
vdf = vdf.drop_duplicates(subset=['county_name'])
md = md.drop_duplicates(subset=['County Name'])

# Step 3: Rename columns
vdf.rename(columns={'county_name': 'county'}, inplace=True)  # Replace old column names with just 'county'
md.rename(columns={'County Name': 'county'}, inplace=True)

# Step 4: Perform the join operation
merged_df = pd.merge(vdf, md, on='county')

# Change county names back to capital letters
merged_df['county'] = merged_df['county'].str.title()
# Out:
# <ipython-input-124-82f6e49a06e0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vdf.rename(columns={'county_name': 'county'}, inplace=True)  # Replace old column names with just 'county'
# <ipython-input-124-82f6e49a06e0>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   md.rename(columns={'County Name': 'county'}, inplace=True)

# %%
merged_df.head()
# Out:
#    year     state  county_fips                county  democrat_votes  \
# 0  2020  VIRGINIA        51510       Alexandria City           66240
# 1  2020  VIRGINIA        51520          Bristol City            2313
# 2  2020  VIRGINIA        51530      Buena Vista City             825
# 3  2020  VIRGINIA        51540  Charlottesville City           20696
# 4  2020  VIRGINIA        51550       Chesapeake City           66377
#
#    republican_votes  total_votes  population Data File Year  County Code  ...  \
# 0             14544        80784    157613.0      2006-2010        510.0  ...
# 1              5347         7660     16912.0      2006-2010        520.0  ...
# 2              1863         2688      6484.0      2006-2010        530.0  ...
# 3              3094        23790     47096.0      2006-2010        540.0  ...
# 4             58180       124557    239982.0      2006-2010        550.0  ...
#
#    Male: Some early_log  Male: High school_log  \
# 0              6.822197               7.257003
# 1              5.521461               6.347389
# 2              5.533389               5.609472
# 3              5.730100               6.513230
# 4              6.272877               7.558517
#
#    Male: Some college or Associate's degree_log  Male: Bachelor's degree_log  \
# 0                                      7.013915                     6.666957
# 1                                      6.152733                     5.337538
# 2                                      5.181784                     4.406719
# 3                                      6.267201                     5.568345
# 4                                      7.427144                     6.501290
#
#    Male: Master's degree or higher_log  Female: Some early_log  \
# 0                             7.125283                6.583409
# 1                             5.252273                5.327876
# 2                             4.615121                5.655992
# 3                             6.251904                5.758902
# 4                             6.683361                6.317165
#
#    Female: High school_log  Female: Some college or Associate's degree_log  \
# 0                 7.272398                                        7.104965
# 1                 6.476972                                        6.204558
# 2                 6.274762                                        5.598422
# 3                 6.566672                                        6.156979
# 4                 7.551712                                        7.471363
#
#    Female: Bachelor's degree_log  Female: Master's degree or higher_log
# 0                       6.582025                               7.053586
# 1                       5.030438                               5.225747
# 2                       4.595120                               5.501258
# 3                       5.541264                               6.182085
# 4                       6.712956                               6.863803
#
# [5 rows x 62 columns]

# %%
# Choose only the columns with population, year, and fips code
pop_df = pop[['YEAR', 'FIPS', 'AV0AA']]

# Function that maps years to year ranges
def map_year_to_range(year):
    if 2000 <= year <= 2007:
        return 2000
    elif 2008 <= year <= 2014:
        return 125  # Year range (2008, 2012) represented by 125
    elif 2015 <= year <= 2024:
        return 195  # Year range (2015, 2019) represented by 195

# Apply the function to map years to year ranges
pop_df['YEAR'] = pop_df['YEAR'].apply(map_year_to_range)

# Aggregate population data by county
pop_df = pop_df.groupby('FIPS').agg({'AV0AA': 'sum'}).reset_index()

# Merge the population data with the merged DataFrame (vdf) on 'FIPS' and 'county_fips'
merged_df = pd.merge(merged_df, pop_df, left_on='county_fips', right_on='FIPS', how='left')

# Drop the duplicate 'FIPS' column if necessary
merged_df.drop(columns=['FIPS'], inplace=True)

# Display the resulting DataFrame
merged_df
# Out:
# <ipython-input-126-54108c213a58>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pop_df['YEAR'] = pop_df['YEAR'].apply(map_year_to_range)
#     year     state  county_fips                 county  democrat_votes  \
# 0   2020  VIRGINIA        51510        Alexandria City           66240
# 1   2020  VIRGINIA        51520           Bristol City            2313
# 2   2020  VIRGINIA        51530       Buena Vista City             825
# 3   2020  VIRGINIA        51540   Charlottesville City           20696
# 4   2020  VIRGINIA        51550        Chesapeake City           66377
# 5   2020  VIRGINIA        51570  Colonial Heights City            2972
# 6   2020  VIRGINIA        51580         Covington City             964
# 7   2020  VIRGINIA        51590          Danville City           11710
# 8   2020  VIRGINIA        51595           Emporia City            1612
# 9   2020  VIRGINIA        51600           Fairfax City            9174
# 10  2020  VIRGINIA        51610      Falls Church City            7146
# 11  2020  VIRGINIA        51620          Franklin City            2525
# 12  2020  VIRGINIA        51630    Fredericksburg City            8517
# 13  2020  VIRGINIA        51640             Galax City             777
# 14  2020  VIRGINIA        51650           Hampton City           46220
# 15  2020  VIRGINIA        51660      Harrisonburg City           11022
# 16  2020  VIRGINIA        51670          Hopewell City            5430
# 17  2020  VIRGINIA        51678         Lexington City            1791
# 18  2020  VIRGINIA        51680         Lynchburg City           18048
# 19  2020  VIRGINIA        51683          Manassas City           10356
# 20  2020  VIRGINIA        51685     Manassas Park City            3992
# 21  2020  VIRGINIA        51690      Martinsville City            3766
# 22  2020  VIRGINIA        51700      Newport News City           53099
# 23  2020  VIRGINIA        51710           Norfolk City           64440
# 24  2020  VIRGINIA        51720            Norton City             464
# 25  2020  VIRGINIA        51730        Petersburg City           12389
# 26  2020  VIRGINIA        51735          Poquoson City            2054
# 27  2020  VIRGINIA        51740        Portsmouth City           30948
# 28  2020  VIRGINIA        51750           Radford City            3358
# 29  2020  VIRGINIA        51760          Richmond City           92175
# 30  2020  VIRGINIA        51770           Roanoke City           26773
# 31  2020  VIRGINIA        51775             Salem City            5148
# 32  2020  VIRGINIA        51790          Staunton City            6981
# 33  2020  VIRGINIA        51800           Suffolk City           28676
# 34  2020  VIRGINIA        51810    Virginia Beach City          117393
# 35  2020  VIRGINIA        51820        Waynesboro City            4961
# 36  2020  VIRGINIA        51830      Williamsburg City            4790
# 37  2020  VIRGINIA        51840        Winchester City            6610
#
#     republican_votes  total_votes  population Data File Year  County Code  \
# 0              14544        80784    157613.0      2006-2010        510.0
# 1               5347         7660     16912.0      2006-2010        520.0
# 2               1863         2688      6484.0      2006-2010        530.0
# 3               3094        23790     47096.0      2006-2010        540.0
# 4              58180       124557    239982.0      2006-2010        550.0
# 5               6007         8979     17428.0      2006-2010        570.0
# 6               1580         2544      5598.0      2006-2010        580.0
# 7               7428        19138     41070.0      2006-2010        590.0
# 8                754         2366      5442.0      2006-2010        595.0
# 9               4007        13181     23531.0      2006-2010        600.0
# 10              1490         8636     14128.0      2006-2010        610.0
# 11              1487         4012      8147.0      2006-2010        620.0
# 12              4037        12554     28622.0      2006-2010        630.0
# 13              1838         2615      6517.0      2006-2010        640.0
# 14             18430        64650    135041.0      2006-2010        650.0
# 15              5591        16613     53273.0      2006-2010        660.0
# 16              4020         9450     22456.0      2006-2010        670.0
# 17               906         2697      7241.0      2006-2010        678.0
# 18             17097        35145     80569.0      2006-2010        680.0
# 19              6256        16612     41174.0      2006-2010        683.0
# 20              1979         5971     16986.0      2006-2010        685.0
# 21              2165         5931     12852.0      2006-2010        690.0
# 22             26377        79476    179673.0      2006-2010        700.0
# 23             23443        87883    244601.0      2006-2010        710.0
# 24              1109         1573      3970.0      2006-2010        720.0
# 25              1584        13973     31362.0      2006-2010        730.0
# 26              5605         7659     12090.0      2006-2010        735.0
# 27             12755        43703     95097.0      2006-2010        740.0
# 28              2786         6144     17691.0      2006-2010        750.0
# 29             16603       108778    226622.0      2006-2010        760.0
# 30             15607        42380     99229.0      2006-2010        770.0
# 31              7683        12831     25317.0      2006-2010        775.0
# 32              5695        12676     24432.0      2006-2010        790.0
# 33             20082        48758     90093.0      2006-2010        800.0
# 34            105087       222480    450201.0      2006-2010        810.0
# 35              5507        10468     22140.0      2006-2010        820.0
# 36              1963         6753     14927.0      2006-2010        830.0
# 37              5221        11831     27897.0      2006-2010        840.0
#
#     ...  Male: High school_log  Male: Some college or Associate's degree_log  \
# 0   ...               7.257003                                      7.013915
# 1   ...               6.347389                                      6.152733
# 2   ...               5.609472                                      5.181784
# 3   ...               6.513230                                      6.267201
# 4   ...               7.558517                                      7.427144
# 5   ...               6.165418                                      5.888878
# 6   ...               5.676754                                      5.433722
# 7   ...               6.851185                                      6.444131
# 8   ...               6.120297                                      4.941642
# 9   ...               5.905362                                      6.137727
# 10  ...               5.252273                                      5.318120
# 11  ...               5.932245                                      5.624018
# 12  ...               6.532334                                      6.124683
# 13  ...               6.287859                                      5.799093
# 14  ...               7.337588                                      7.295056
# 15  ...               6.812345                                      6.267201
# 16  ...               6.741701                                      6.251904
# 17  ...               6.190315                                      4.744932
# 18  ...               6.959399                                      6.719013
# 19  ...               6.806829                                      6.450470
# 20  ...               6.156979                                      5.913503
# 21  ...               6.070738                                      5.655992
# 22  ...               7.401231                                      7.242082
# 23  ...               7.666690                                      7.479864
# 24  ...               5.717028                                      5.351858
# 25  ...               6.812345                                      6.400257
# 26  ...               5.564520                                      5.648974
# 27  ...               7.252762                                      6.985642
# 28  ...               6.042633                                      5.627621
# 29  ...               7.643962                                      7.213032
# 30  ...               7.301822                                      7.033506
# 31  ...               6.329721                                      6.173786
# 32  ...               6.421622                                      6.200509
# 33  ...               7.062192                                      6.793466
# 34  ...               7.682482                                      7.784057
# 35  ...               6.533789                                      6.146329
# 36  ...               5.579730                                      5.641907
# 37  ...               6.880384                                      6.364751
#
#     Male: Bachelor's degree_log  Male: Master's degree or higher_log  \
# 0                      6.666957                             7.125283
# 1                      5.337538                             5.252273
# 2                      4.406719                             4.615121
# 3                      5.568345                             6.251904
# 4                      6.501290                             6.683361
# 5                      5.117994                             5.231109
# 6                      4.143135                             5.680173
# 7                      5.451038                             5.652489
# 8                      4.234107                             4.859812
# 9                      5.497168                             6.131226
# 10                     5.062595                             5.942799
# 11                     4.454347                             5.361292
# 12                     5.231109                             5.686975
# 13                     4.890349                             4.787492
# 14                     6.202536                             6.428105
# 15                     5.872118                             6.054439
# 16                     4.736198                             5.123964
# 17                     4.624973                             5.323010
# 18                     5.758902                             6.173786
# 19                     5.560682                             5.755742
# 20                     4.770685                             5.043425
# 21                     4.897840                             5.241747
# 22                     6.212606                             6.586172
# 23                     6.591674                             6.651572
# 24                     4.094345                             5.323010
# 25                     5.356586                             5.187386
# 26                     4.941642                             5.262690
# 27                     5.834811                             6.030685
# 28                     4.927254                             5.176150
# 29                     6.429719                             6.800170
# 30                     5.877736                             6.311735
# 31                     5.446737                             5.631212
# 32                     5.411646                             5.556828
# 33                     5.899897                             6.253829
# 34                     6.803505                             7.145196
# 35                     5.252273                             5.575949
# 36                     5.068904                             5.429346
# 37                     5.429346                             6.003887
#
#     Female: Some early_log  Female: High school_log  \
# 0                 6.583409                 7.272398
# 1                 5.327876                 6.476972
# 2                 5.655992                 6.274762
# 3                 5.758902                 6.566672
# 4                 6.317165                 7.551712
# 5                 5.017280                 6.282267
# 6                 5.932245                 5.820083
# 7                 5.991465                 6.920672
# 8                 5.247024                 5.897154
# 9                 5.170484                 6.098074
# 10                5.451038                 6.095825
# 11                5.049856                 6.163315
# 12                5.846439                 6.539586
# 13                6.163315                 6.129050
# 14                6.234411                 7.400010
# 15                6.242223                 6.849066
# 16                5.560682                 6.830874
# 17                5.533389                 6.052089
# 18                6.100319                 6.972606
# 19                6.298949                 6.617403
# 20                5.866468                 6.175867
# 21                5.308268                 6.282267
# 22                6.354370                 7.472501
# 23                6.513230                 7.678326
# 24                5.587249                 5.513429
# 25                5.924256                 6.887553
# 26                5.356586                 5.710427
# 27                6.232448                 7.183871
# 28                5.564520                 5.777652
# 29                6.833032                 7.676010
# 30                6.493754                 7.268223
# 31                5.758902                 6.398595
# 32                5.568345                 6.586172
# 33                6.208590                 7.068172
# 34                6.498282                 7.671827
# 35                5.852202                 6.641182
# 36                4.262680                 5.783825
# 37                5.771441                 6.461468
#
#     Female: Some college or Associate's degree_log  \
# 0                                         7.104965
# 1                                         6.204558
# 2                                         5.598422
# 3                                         6.156979
# 4                                         7.471363
# 5                                         6.098074
# 6                                         5.552960
# 7                                         6.712956
# 8                                         5.433722
# 9                                         6.086775
# 10                                        5.575949
# 11                                        5.697093
# 12                                        6.126869
# 13                                        5.872118
# 14                                        7.240650
# 15                                        6.361302
# 16                                        6.302619
# 17                                        5.170484
# 18                                        6.729824
# 19                                        6.463029
# 20                                        5.973810
# 21                                        6.082219
# 22                                        7.461066
# 23                                        7.398174
# 24                                        5.389072
# 25                                        6.222576
# 26                                        6.028279
# 27                                        6.993933
# 28                                        5.942799
# 29                                        7.356918
# 30                                        7.044033
# 31                                        6.255750
# 32                                        6.198479
# 33                                        7.000334
# 34                                        7.811163
# 35                                        6.120297
# 36                                        5.777652
# 37                                        6.308098
#
#     Female: Bachelor's degree_log  Female: Master's degree or higher_log  \
# 0                        6.582025                               7.053586
# 1                        5.030438                               5.225747
# 2                        4.595120                               5.501258
# 3                        5.541264                               6.182085
# 4                        6.712956                               6.863803
# 5                        4.852030                               5.198497
# 6                        4.219508                               5.347108
# 7                        5.347108                               5.537334
# 8                        4.262680                               4.499810
# 9                        5.666427                               5.902633
# 10                       5.147494                               5.755742
# 11                       4.644391                               5.030438
# 12                       5.602119                               5.590987
# 13                       4.510860                               5.758902
# 14                       6.324359                               6.373320
# 15                       5.855072                               6.146329
# 16                       5.298317                               5.093750
# 17                       4.927254                               5.389072
# 18                       5.717028                               6.109248
# 19                       5.455321                               5.855072
# 20                       4.955827                               5.141664
# 21                       4.828314                               5.267858
# 22                       6.493754                               6.390241
# 23                       6.448889                               6.621406
# 24                       4.418841                               5.278115
# 25                       5.575949                               5.459586
# 26                       4.836282                               5.252273
# 27                       6.006353                               6.061457
# 28                       5.159055                               5.393628
# 29                       6.569481                               6.778785
# 30                       5.910797                               6.139885
# 31                       5.484797                               5.755742
# 32                       5.442418                               5.796058
# 33                       6.063785                               6.150603
# 34                       7.038784                               7.110696
# 35                       5.153292                               5.384495
# 36                       4.927254                               5.347108
# 37                       5.488938                               5.843544
#
#         AV0AA
# 0    426233.0
# 1     52026.0
# 2     19512.0
# 3    135368.0
# 4    662399.0
# 5     51751.0
# 6     17804.0
# 7    132666.0
# 8     16932.0
# 9     67741.0
# 10    36805.0
# 11    25024.0
# 12    72833.0
# 13    20296.0
# 14   418949.0
# 15   142784.0
# 16    67311.0
# 17    21098.0
# 18   221495.0
# 19   114252.0
# 20    41685.0
# 21    42122.0
# 22   540654.0
# 23   722060.0
# 24    11845.0
# 25    97328.0
# 26    35766.0
# 27   291448.0
# 28    50061.0
# 29   629760.0
# 30   290882.0
# 31    74856.0
# 32    72191.0
# 33   237986.0
# 34  1314986.0
# 35    62690.0
# 36    41132.0
# 37    77812.0
#
# [38 rows x 63 columns]

# %%
merged_df.to_csv("real_combined_data.csv")

# %%
merged_df.shape
# Out:
# (38, 63)

# %%
vdf.shape
# Out:
# (167, 8)

# %%
md.shape
# Out:
# (134, 55)
