# %% [markdown]
# # Healthcare Database Python Code

# %%
# Import all necessary libraries and packages
import os
import pandas as pd
import json
import pprint
import requests
import requests.exceptions
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# ## Load CSV File and Convert to DF

# %%
data_dir = os.path.join(os.getcwd(), 'downloads')
data_file = os.path.join(data_dir, 'admission_data.csv')

try:
    admissions_df = pd.read_csv(data_file, header=0, index_col=0)
    result_head = admissions_df.head()
except FileNotFoundError as errf:
     print(f"Error: File not found - {errf}")
     result_head = pd.DataFrame()
except pd.errors.EmptyDataError as erre:
    print(f"Error: The CSV file is empty - {erre}")
    result_head = pd.DataFrame()
except pd.errors.ParserError as errp:
    print(f"Error: There was an error parsing the CSV file - {errp}")
    result_head = pd.DataFrame()
except Exception as err:
    print(f"An unexpected error occurred - {err}")
    result_head = pd.DataFrame()
    

result_head
# Out:
#          Hospital_code Hospital_type_code  City_Code_Hospital  \
# case_id
# 1                    8                  c                   3
# 2                    2                  c                   5
# 3                   10                  e                   1
# 4                   26                  b                   2
# 5                   26                  b                   2
#
#         Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# case_id
# 1                          Z                                  3  radiotherapy
# 2                          Z                                  2  radiotherapy
# 3                          X                                  2    anesthesia
# 4                          Y                                  2  radiotherapy
# 5                          Y                                  2  radiotherapy
#
#         Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# case_id
# 1               R                  F        2.0      31397                7.0
# 2               S                  F        2.0      31397                7.0
# 3               S                  E        2.0      31397                7.0
# 4               R                  D        2.0      31397                7.0
# 5               S                  D        2.0      31397                7.0
#
#         Type of Admission Severity of Illness  Visitors with Patient    Age  \
# case_id
# 1               Emergency             Extreme                      2  51-60
# 2                  Trauma             Extreme                      2  51-60
# 3                  Trauma             Extreme                      2  51-60
# 4                  Trauma             Extreme                      2  51-60
# 5                  Trauma             Extreme                      2  51-60
#
#          Admission_Deposit   Stay
# case_id
# 1                   4911.0   0-10
# 2                   5954.0  41-50
# 3                   4745.0  31-40
# 4                   7272.0  41-50
# 5                   5558.0  41-50

# %% [markdown]
# ### Export as SQL File

# %%
# Get information for connection
try:
    with open('env_info.json') as f:
        info = json.load(f)
except FileNotFoundError:
    print("Error: 'env_info.json' file not found.")
except json.JSONDecodeError:
    print("Error: unable to parse 'env_info.json'. Make sure this is a valid JSON file.")
try:
    db_user = info['DB_USER']
    db_password = info['DB_PASSWORD']
    db_host = info['DB_HOST']
    db_port = info['DB_PORT']
    db_name = info['DB_NAME']
    
# Check to make sure environment variables are there, return error statement if not
except KeyError as e:
    print(f"Error: Missing environment variable {e}")

# Create a MySQL engine
engine = create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')

# Export the Dataframe to MySQL
try:
    admissions_df.to_sql(name = 'Admissions', con = engine, index = True, if_exists = 'replace')
    print("DataFrame sucessfully exported to MySQL!")
except Exception as e:
    print(f"Error: Unable to export DataFrame to MySQL. {e}")
# Out:
# DataFrame sucessfully exported to MySQL!

# %% [markdown]
# ## Get Data from Hospital API

# %%
def get_hospital_info(state):
    url = f"https://www.communitybenefitinsight.org/api/get_hospitals.php?state={state}"
    
    try:
        response = requests.request("GET", url)
        response.raise_for_status()
        data = response.json()
        
        if "error" in data:
            return "Error in API response: {data['error']}"
        
    except requests.exceptions.HTTPError as errh:
        return "An Http Error occurred: " + repr(errh)
    except requests.exceptions.ConnectionError as errc:
        return "An Error Connecting to the API occurred: " + repr(errc)
    except requests.exceptions.Timeout as errt:
        return "A Timeout Error occurred: " + repr(errt)
    except json.JSONDecodeError as errj:
        return "JSON Decode Error: " + repr(errj)
    except requests.exceptions.RequestException as err:
        return "An Unknown Error occurred: " + repr(err)


    return data

# %% [markdown]
# ### Get the Hospital Data Output (JSON)

# %%
state = input('Enter a state using its two-letter abbreviation: ')
hospital_data = get_hospital_info(state)
# Out:
# Enter a state using its two-letter abbreviation: NJ

# %% [markdown]
# ### Convert to Dataframe

# %%
df = pd.DataFrame(hospital_data)
df
# Out:
#    hospital_id hospital_org_id        ein  \
# 0         1903            1491  010649794
# 1         1904            1493  851296795
# 2         1905            1491  010649794
# 3         1906            1495  221537688
# 4         1907            1496  221494446
# ..         ...             ...        ...
# 59        1962            1508  210634532
# 60        1963            1542  223284894
# 61        1964            1522  223319886
# 62        1965            1491  010649794
# 63        1966            1493  851296795
#
#                                     name  \
# 0   Hackensack University Medical Center
# 1      Newark Beth Israel Medical Center
# 2               Palisades Medical Center
# 3               Hunterdon Medical Center
# 4              St Marys General Hospital
# ..                                   ...
# 59                      Virtua - Marlton
# 60   Meadowlands Hospital Medical Center
# 61           St Clares Hospital - Sussex
# 62      Hackensack Umc At Pascack Valley
# 63        Childrens Specialized Hopsital
#
#                                  name_cr       street_address          city  \
# 0   Hackensack University Medical Center   30 Prospect Avenue    Hackensack
# 1      Newark Beth Israel Medical Center     201 Lyons Avenue        Newark
# 2               Palisades Medical Center      7600 River Road  North Bergen
# 3               Hunterdon Medical Center   2100 Wescott Drive    Flemington
# 4            St Marys Hospital - Passaic        350 Boulevard       Passaic
# ..                                   ...                  ...           ...
# 59                                            Rt 73  Brick Rd       Marlton
# 60                                        55 Meadowlands Pkwy      Secaucus
# 61           St Clares Hospital - Sussex     20 Walnut Street        Sussex
# 62      Hackensack Umc At Pascack Valley    250 Old Hook Road      Westwood
# 63        Childrens Specialized Hopsital  150 Providence Road  Mountainside
#
#    state zip_code fips_state_and_county_code hospital_bed_count chrch_affl_f  \
# 0     NJ    07601                      34003                781            N
# 1     NJ    07112                      34013                665            N
# 2     NJ    07047                      34017                202            N
# 3     NJ    08822                      34019                184            N
# 4     NJ    07055                      34031                286            N
# ..   ...      ...                        ...                ...          ...
# 59    NJ    08053                      34005                204            N
# 60    NJ    07094                      34017                208            N
# 61    NJ    07461                      34037                106            Y
# 62    NJ    07675                      34003                128            N
# 63    NJ    07094                      34023                 90            N
#
#    urban_location_f children_hospital_f memb_counc_teach_hosps_f  \
# 0                 Y                   N                        Y
# 1                 Y                   N                        Y
# 2                 Y                   N                        N
# 3                 Y                   N                        Y
# 4                 Y                   N                        N
# ..              ...                 ...                      ...
# 59                Y                   N                        N
# 60                Y                   N                        N
# 61                Y                   N                        N
# 62                Y                   N                        Y
# 63                Y                   Y                        Y
#
#    medicare_provider_number             county hospital_bed_size  \
# 0                    310001      Bergen County         >299 beds
# 1                    310002       Essex County         >299 beds
# 2                    310003      Hudson County      100-299 beds
# 3                    310005   Hunterdon County      100-299 beds
# 4                    310006     Passaic County      100-299 beds
# ..                      ...                ...               ...
# 59                   310117  Burlington County      100-299 beds
# 60                   310118      Hudson County      100-299 beds
# 61                   310120      Sussex County      100-299 beds
# 62                   310130      Bergen County      100-299 beds
# 63                   313300   Middlesex County         <100 beds
#
#            updated_dt
# 0   November 20, 2023
# 1   November 20, 2023
# 2   November 20, 2023
# 3   November 20, 2023
# 4   November 20, 2023
# ..                ...
# 59  November 20, 2023
# 60  November 20, 2023
# 61  November 20, 2023
# 62  November 20, 2023
# 63  November 20, 2023
#
# [64 rows x 19 columns]

# %% [markdown]
# ### Export as SQL File

# %%
# Get information for connection
try:
    with open('env_info.json') as f:
        info = json.load(f)
except FileNotFoundError:
    print("Error: 'env_info.json' file not found.")
except json.JSONDecodeError:
    print("Error: unable to parse 'env_info.json'. Make sure this is a valid JSON file.")
try:
    db_user = info['DB_USER']
    db_password = info['DB_PASSWORD']
    db_host = info['DB_HOST']
    db_port = info['DB_PORT']
    db_name = info['DB_NAME']
    
# Check to make sure environment variables are there, return error statement if not
except KeyError as e:
    print(f"Error: Missing environment variable {e}")

# Create a MySQL engine
engine = create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')

# Export the Dataframe to MySQL
try:
    df.to_sql(name = 'Hospitals', con = engine, index = False, if_exists = 'replace')
    print("DataFrame sucessfully exported to MySQL!")
except Exception as e:
    print(f"Error: Unable to export DataFrame to MySQL. {e}")
# Out:
# DataFrame sucessfully exported to MySQL!
